# %%
# Import libraries
from datetime import datetime
import yfinance as yf
import pandas as pd 
from pandas_datareader import data as web
import numpy as np 
from pypfopt.efficient_frontier import EfficientFrontier 
from pypfopt import risk_models
from pypfopt import expected_returns
import seaborn as sns
import matplotlib.pyplot as plt

from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
def get_data(startdate, enddate, stocklist): 
    """
    * This function retrieves the Adjusted close price from the historical data 
      for each stock in the list, for the given date range.
    * Enter dates as "yyyymmdd". 
    """
    start_date=datetime.strptime(startdate, '%Y%m%d').date()
    end_date=datetime.strptime(enddate, '%Y%m%d').date()
    data = yf.download(stocklist, start=start_date, end=end_date, progress=False)
    return data['Adj Close'].copy()

# %%
def split(df,date): 
    """This function divides the dataframe in a train
    and test test splitted by the date given.
    """
    train=df.loc[df.index<date]
    test=df.loc[df.index>=date]
    return train, test

# %%
def plot_close(df, date):
    """
    In this function you can enter a date as 'yyyymmdd' and 
    see the plot of train and test  
    """
    train,test= split(df,date)

    fig, ax = plt.subplots(figsize=(20, 5))
    train.plot(ax=ax, label='Training', title='Adjusted Closing Prices')
    test.plot(ax=ax, label='Test Set')
    ax.axvline(date, color='black', ls='--')
    ax.legend(['Training', 'Test'])
    plt.show()

# %%
def add_lag(df):
    """This function adds two lag features to the dataframe.
    It assumes the latest column is the target. 
    """
    df=df.copy()
    df['t-1']=df['MSFT'].shift(1)
    df['t-2']=df['MSFT'].shift(2)
    df.dropna(inplace=True)
    return df

# %%
def prepare_data(df, date):
    # Add lag to the DataFrame
    df_lagged = df.copy()
    df_lagged['t-1'] = df_lagged['MSFT'].shift(1)
    df_lagged['t-2'] = df_lagged['MSFT'].shift(2)
    df_lagged.dropna(inplace=True)
    
    # Split the DataFrame into train and test sets
    train,test= split(df_lagged,date)
    
    # Split the train and test sets into features and target
    X_train = train[['t-1', 't-2']]
    y_train = train['MSFT']
    X_test = test[['t-1', 't-2']]
    y_test = test['MSFT']
    
    # Combine train and test sets into X and y
    X = df_lagged[['t-1', 't-2']]
    y = df_lagged['MSFT']
    
    return X_train, X_test, y_train, y_test, X, y

# %% [markdown]
# We will now use the functions that we have defined.

# %%
#We will make a prediction with MSFT 

stock_list = ['MSFT', 'MMC', 'NI', 'BAX', 'CNP', 'TGT', 'JPM', 'BA']
close_df=get_data("20180101","20230101",stock_list)
close_df=close_df[['MSFT']]
close_df.head()

# We will split the data in train and test set and plot the stock price
date="20221201"
plot_close(close_df, date)

# %%
#Store all the values
X_train, X_test, y_train, y_test, X, y=prepare_data(close_df, date)

# %% [markdown]
# We'll try to fit a model but use a gridsearch in order to find the best parameters.

# %%
model = XGBRegressor()
model.fit(X_train, y_train)

param_grid = {
    
    'n_estimators': [100, 500, 1000],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.3]
}

grid_search = GridSearchCV(model, param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# Let's use this model and add early stopping in order to avoid overfitting:

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=500, early_stopping_rounds=50, learning_rate=0.01, max_depth=7)
xgb.fit(X_train, y_train, eval_set=[(X_train, y_train),(X_test,y_test)], verbose=True)
# Out:
# [0]	validation_0-rmse:200.96116	validation_1-rmse:242.22974
# [1]	validation_0-rmse:198.96944	validation_1-rmse:239.86210
# [2]	validation_0-rmse:196.99738	validation_1-rmse:237.50959
# [3]	validation_0-rmse:195.04445	validation_1-rmse:235.16242
# [4]	validation_0-rmse:193.11107	validation_1-rmse:232.83862
# [5]	validation_0-rmse:191.19672	validation_1-rmse:230.53070
# [6]	validation_0-rmse:189.30207	validation_1-rmse:228.28367
# [7]	validation_0-rmse:187.42565	validation_1-rmse:226.02246
# [8]	validation_0-rmse:185.56853	validation_1-rmse:223.82019
# [9]	validation_0-rmse:183.72933	validation_1-rmse:221.60320
# [10]	validation_0-rmse:181.90884	validation_1-rmse:219.39898
# [11]	validation_0-rmse:180.10610	validation_1-rmse:217.21355
# [12]	validation_0-rmse:178.32146	validation_1-rmse:215.05332
# [13]	validation_0-rmse:176.55495	validation_1-rmse:212.95909
# [14]	validation_0-rmse:174.80565	validation_1-rmse:210.84177
# [15]	validation_0-rmse:173.07349	validation_1-rmse:208.72371
# [16]	validation_0-rmse:171.35880	validation_1-rmse:206.64684
# [17]	validation_0-rmse:169.66096	validation_1-rmse:204.57084
# [18]	validation_0-rmse:167.98012	validation_1-rmse:202.54434
# [19]	validation_0-rmse:166.31588	validation_1-rmse:200.50872
# [20]	validation_0-rmse:164.66831	validation_1-rmse:198.52250
# [21]	validation_0-rmse:163.03705	validation_1-rmse:196.53004
# [22]	validation_0-rmse:161.42201	validation_1-rmse:194.58011
# [23]	validation_0-rmse:159.82304	validation_1-rmse:192.62710
# [24]	validation_0-rmse:158.24004	validation_1-rmse:190.70700
# [25]	validation_0-rmse:156.67267	validation_1-rmse:188.81410
# [26]	validation_0-rmse:155.12095	validation_1-rmse:186.94366
# [27]	validation_0-rmse:153.58463	validation_1-rmse:185.07775
# [28]	validation_0-rmse:152.06354	validation_1-rmse:183.21686
# [29]	validation_0-rmse:150.55758	validation_1-rmse:181.39849
# [30]	validation_0-rmse:149.06659	validation_1-rmse:179.57471
# [31]	validation_0-rmse:147.59039	validation_1-rmse:177.82596
# [32]	validation_0-rmse:146.12893	validation_1-rmse:176.03823
# [33]	validation_0-rmse:144.68201	validation_1-rmse:174.26831
# [34]	validation_0-rmse:143.24935	validation_1-rmse:172.53447
# [35]	validation_0-rmse:141.83097	validation_1-rmse:170.81965
# [36]	validation_0-rmse:140.42666	validation_1-rmse:169.12612
# [37]	validation_0-rmse:139.03634	validation_1-rmse:167.42561
# [38]	validation_0-rmse:137.65981	validation_1-rmse:165.75992
# [39]	validation_0-rmse:136.29694	validation_1-rmse:164.09318
# [40]	validation_0-rmse:134.94771	validation_1-rmse:162.47429
# [41]	validation_0-rmse:133.61171	validation_1-rmse:160.86928
# [42]	validation_0-rmse:132.28889	validation_1-rmse:159.24610
# [43]	validation_0-rmse:130.97930	validation_1-rmse:157.65957
# [44]	validation_0-rmse:129.68268	validation_1-rmse:156.06883
# [45]	validation_0-rmse:128.39896	validation_1-rmse:154.54941
# [46]	validation_0-rmse:127.12798	validation_1-rmse:152.99027
# [47]	validation_0-rmse:125.86963	validation_1-rmse:151.46950
# [48]	validation_0-rmse:124.62344	validation_1-rmse:149.96548
# [49]	validation_0-rmse:123.38988	validation_1-rmse:148.45234
# [50]	validation_0-rmse:122.16825	validation_1-rmse:146.96978
# [51]	validation_0-rmse:120.95904	validation_1-rmse:145.48678
# [52]	validation_0-rmse:119.76156	validation_1-rmse:144.03698
# [53]	validation_0-rmse:118.57626	validation_1-rmse:142.58362
# [54]	validation_0-rmse:117.40276	validation_1-rmse:141.18622
# [55]	validation_0-rmse:116.24058	validation_1-rmse:139.78749
# [56]	validation_0-rmse:115.09013	validation_1-rmse:138.37706
# [57]	validation_0-rmse:113.95121	validation_1-rmse:136.98078
# [58]	validation_0-rmse:112.82329	validation_1-rmse:135.62507
# [59]	validation_0-rmse:111.70676	validation_1-rmse:134.25798
# [60]	validation_0-rmse:110.60102	validation_1-rmse:132.93504
# [61]	validation_0-rmse:109.50654	validation_1-rmse:131.59503
# [62]	validation_0-rmse:108.42265	validation_1-rmse:130.28502
# [63]	validation_0-rmse:107.34984	validation_1-rmse:128.97013
# [64]	validation_0-rmse:106.28752	validation_1-rmse:127.68967
# [65]	validation_0-rmse:105.23585	validation_1-rmse:126.40249
# [66]	validation_0-rmse:104.19472	validation_1-rmse:125.12428
# [67]	validation_0-rmse:103.16354	validation_1-rmse:123.87869
# [68]	validation_0-rmse:102.14288	validation_1-rmse:122.62963
# [69]	validation_0-rmse:101.13207	validation_1-rmse:121.41566
# [70]	validation_0-rmse:100.13158	validation_1-rmse:120.18764
# [71]	validation_0-rmse:99.14071	validation_1-rmse:118.99045
# [72]	validation_0-rmse:98.16003	validation_1-rmse:117.79049
# [73]	validation_0-rmse:97.18878	validation_1-rmse:116.61045
# [74]	validation_0-rmse:96.22748	validation_1-rmse:115.44493
# [75]	validation_0-rmse:95.27537	validation_1-rmse:114.30038
# [76]	validation_0-rmse:94.33281	validation_1-rmse:113.14750
# [77]	validation_0-rmse:93.39962	validation_1-rmse:112.01126
# [78]	validation_0-rmse:92.47549	validation_1-rmse:110.90032
# [79]	validation_0-rmse:91.56095	validation_1-rmse:109.78010
# [80]	validation_0-rmse:90.65551	validation_1-rmse:108.68666
# [81]	validation_0-rmse:89.75869	validation_1-rmse:107.60403
# [82]	validation_0-rmse:88.87092	validation_1-rmse:106.51841
# [83]	validation_0-rmse:87.99178	validation_1-rmse:105.46184
# [84]	validation_0-rmse:87.12156	validation_1-rmse:104.39682
# [85]	validation_0-rmse:86.25997	validation_1-rmse:103.35231
# [86]	validation_0-rmse:85.40712	validation_1-rmse:102.30528
# [87]	validation_0-rmse:84.56237	validation_1-rmse:101.29006
# [88]	validation_0-rmse:83.72639	validation_1-rmse:100.27756
# [89]	validation_0-rmse:82.89841	validation_1-rmse:99.28153
# [90]	validation_0-rmse:82.07876	validation_1-rmse:98.27864
# [91]	validation_0-rmse:81.26714	validation_1-rmse:97.29500
# [92]	validation_0-rmse:80.46358	validation_1-rmse:96.30478
# [93]	validation_0-rmse:79.66817	validation_1-rmse:95.32445
# [94]	validation_0-rmse:78.88065	validation_1-rmse:94.38777
# [95]	validation_0-rmse:78.10071	validation_1-rmse:93.45112
# [96]	validation_0-rmse:77.32863	validation_1-rmse:92.49991
# [97]	validation_0-rmse:76.56413	validation_1-rmse:91.59666
# [98]	validation_0-rmse:75.80717	validation_1-rmse:90.66979
# [99]	validation_0-rmse:75.05774	validation_1-rmse:89.75218
# [100]	validation_0-rmse:74.31609	validation_1-rmse:88.85435
# [101]	validation_0-rmse:73.58150	validation_1-rmse:87.96915
# [102]	validation_0-rmse:72.85417	validation_1-rmse:87.07877
# [103]	validation_0-rmse:72.13408	validation_1-rmse:86.19704
# [104]	validation_0-rmse:71.42116	validation_1-rmse:85.35962
# [105]	validation_0-rmse:70.71528	validation_1-rmse:84.49479
# [106]	validation_0-rmse:70.01645	validation_1-rmse:83.63925
# [107]	validation_0-rmse:69.32484	validation_1-rmse:82.80215
# [108]	validation_0-rmse:68.63985	validation_1-rmse:81.97471
# [109]	validation_0-rmse:67.96161	validation_1-rmse:81.14297
# [110]	validation_0-rmse:67.29014	validation_1-rmse:80.31955
# [111]	validation_0-rmse:66.62541	validation_1-rmse:79.53419
# [112]	validation_0-rmse:65.96721	validation_1-rmse:78.72720
# [113]	validation_0-rmse:65.31556	validation_1-rmse:77.92370
# [114]	validation_0-rmse:64.67064	validation_1-rmse:77.14334
# [115]	validation_0-rmse:64.03186	validation_1-rmse:76.38234
# [116]	validation_0-rmse:63.39945	validation_1-rmse:75.60716
# [117]	validation_0-rmse:62.77333	validation_1-rmse:74.85133
# [118]	validation_0-rmse:62.15345	validation_1-rmse:74.08829
# [119]	validation_0-rmse:61.53984	validation_1-rmse:73.35562
# [120]	validation_0-rmse:60.93220	validation_1-rmse:72.61107
# [121]	validation_0-rmse:60.33052	validation_1-rmse:71.88677
# [122]	validation_0-rmse:59.73493	validation_1-rmse:71.15766
# [123]	validation_0-rmse:59.14520	validation_1-rmse:70.46524
# [124]	validation_0-rmse:58.56138	validation_1-rmse:69.75087
# [125]	validation_0-rmse:57.98336	validation_1-rmse:69.04504
# [126]	validation_0-rmse:57.41116	validation_1-rmse:68.34636
# [127]	validation_0-rmse:56.84459	validation_1-rmse:67.64871
# [128]	validation_0-rmse:56.28371	validation_1-rmse:66.98257
# [129]	validation_0-rmse:55.72838	validation_1-rmse:66.30318
# [130]	validation_0-rmse:55.17848	validation_1-rmse:65.64928
# [131]	validation_0-rmse:54.63412	validation_1-rmse:64.98439
# [132]	validation_0-rmse:54.09530	validation_1-rmse:64.32680
# [133]	validation_0-rmse:53.56161	validation_1-rmse:63.68276
# [134]	validation_0-rmse:53.03334	validation_1-rmse:63.03675
# [135]	validation_0-rmse:52.51020	validation_1-rmse:62.40527
# [136]	validation_0-rmse:51.99230	validation_1-rmse:61.79801
# [137]	validation_0-rmse:51.47952	validation_1-rmse:61.17914
# [138]	validation_0-rmse:50.97205	validation_1-rmse:60.56241
# [139]	validation_0-rmse:50.46943	validation_1-rmse:59.95581
# [140]	validation_0-rmse:49.97182	validation_1-rmse:59.35528
# [141]	validation_0-rmse:49.47932	validation_1-rmse:58.75389
# [142]	validation_0-rmse:48.99157	validation_1-rmse:58.16530
# [143]	validation_0-rmse:48.50870	validation_1-rmse:57.58259
# [144]	validation_0-rmse:48.03065	validation_1-rmse:57.00572
# [145]	validation_0-rmse:47.55734	validation_1-rmse:56.44528
# [146]	validation_0-rmse:47.08876	validation_1-rmse:55.87993
# [147]	validation_0-rmse:46.62497	validation_1-rmse:55.31717
# [148]	validation_0-rmse:46.16562	validation_1-rmse:54.76395
# [149]	validation_0-rmse:45.71089	validation_1-rmse:54.21542
# [150]	validation_0-rmse:45.26071	validation_1-rmse:53.67239
# [151]	validation_0-rmse:44.81513	validation_1-rmse:53.12829
# [152]	validation_0-rmse:44.37387	validation_1-rmse:52.59606
# [153]	validation_0-rmse:43.93703	validation_1-rmse:52.06120
# [154]	validation_0-rmse:43.50452	validation_1-rmse:51.54799
# [155]	validation_0-rmse:43.07632	validation_1-rmse:51.03159
# [156]	validation_0-rmse:42.65240	validation_1-rmse:50.52038
# [157]	validation_0-rmse:42.23278	validation_1-rmse:50.01042
# [158]	validation_0-rmse:41.81716	validation_1-rmse:49.51675
# [159]	validation_0-rmse:41.40570	validation_1-rmse:49.03589
# [160]	validation_0-rmse:40.99844	validation_1-rmse:48.53841
# [161]	validation_0-rmse:40.59524	validation_1-rmse:48.05235
# [162]	validation_0-rmse:40.19606	validation_1-rmse:47.56029
# [163]	validation_0-rmse:39.80088	validation_1-rmse:47.08389
# [164]	validation_0-rmse:39.40962	validation_1-rmse:46.60287
# [165]	validation_0-rmse:39.02231	validation_1-rmse:46.13598
# [166]	validation_0-rmse:38.63882	validation_1-rmse:45.66453
# [167]	validation_0-rmse:38.25911	validation_1-rmse:45.21183
# [168]	validation_0-rmse:37.88319	validation_1-rmse:44.75410
# [169]	validation_0-rmse:37.51110	validation_1-rmse:44.29471
# [170]	validation_0-rmse:37.14266	validation_1-rmse:43.84615
# [171]	validation_0-rmse:36.77796	validation_1-rmse:43.39559
# [172]	validation_0-rmse:36.41685	validation_1-rmse:42.95600
# [173]	validation_0-rmse:36.05940	validation_1-rmse:42.51955
# [174]	validation_0-rmse:35.70547	validation_1-rmse:42.08875
# [175]	validation_0-rmse:35.35514	validation_1-rmse:41.66099
# [176]	validation_0-rmse:35.00814	validation_1-rmse:41.25097
# [177]	validation_0-rmse:34.66470	validation_1-rmse:40.83371
# [178]	validation_0-rmse:34.32478	validation_1-rmse:40.41546
# [179]	validation_0-rmse:33.98819	validation_1-rmse:40.00593
# [180]	validation_0-rmse:33.65502	validation_1-rmse:39.59923
# [181]	validation_0-rmse:33.32513	validation_1-rmse:39.19791
# [182]	validation_0-rmse:32.99858	validation_1-rmse:38.80195
# [183]	validation_0-rmse:32.67516	validation_1-rmse:38.41987
# [184]	validation_0-rmse:32.35508	validation_1-rmse:38.03118
# [185]	validation_0-rmse:32.03824	validation_1-rmse:37.64687
# [186]	validation_0-rmse:31.72453	validation_1-rmse:37.27648
# [187]	validation_0-rmse:31.41378	validation_1-rmse:36.90498
# [188]	validation_0-rmse:31.10636	validation_1-rmse:36.52554
# [189]	validation_0-rmse:30.80198	validation_1-rmse:36.16629
# [190]	validation_0-rmse:30.50066	validation_1-rmse:35.79997
# [191]	validation_0-rmse:30.20238	validation_1-rmse:35.43599
# [192]	validation_0-rmse:29.90701	validation_1-rmse:35.08631
# [193]	validation_0-rmse:29.61468	validation_1-rmse:34.73151
# [194]	validation_0-rmse:29.32521	validation_1-rmse:34.38887
# [195]	validation_0-rmse:29.03873	validation_1-rmse:34.03643
# [196]	validation_0-rmse:28.75504	validation_1-rmse:33.70069
# [197]	validation_0-rmse:28.47410	validation_1-rmse:33.36638
# [198]	validation_0-rmse:28.19609	validation_1-rmse:33.03741
# [199]	validation_0-rmse:27.92091	validation_1-rmse:32.70167
# [200]	validation_0-rmse:27.64842	validation_1-rmse:32.37848
# [201]	validation_0-rmse:27.37873	validation_1-rmse:32.04967
# [202]	validation_0-rmse:27.11155	validation_1-rmse:31.73613
# [203]	validation_0-rmse:26.84725	validation_1-rmse:31.41562
# [204]	validation_0-rmse:26.58556	validation_1-rmse:31.10538
# [205]	validation_0-rmse:26.32630	validation_1-rmse:30.80354
# [206]	validation_0-rmse:26.06986	validation_1-rmse:30.49958
# [207]	validation_0-rmse:25.81603	validation_1-rmse:30.18634
# [208]	validation_0-rmse:25.56466	validation_1-rmse:29.88603
# [209]	validation_0-rmse:25.31586	validation_1-rmse:29.59127
# [210]	validation_0-rmse:25.06962	validation_1-rmse:29.29287
# [211]	validation_0-rmse:24.82582	validation_1-rmse:29.00408
# [212]	validation_0-rmse:24.58444	validation_1-rmse:28.71838
# [213]	validation_0-rmse:24.34548	validation_1-rmse:28.43440
# [214]	validation_0-rmse:24.10899	validation_1-rmse:28.14608
# [215]	validation_0-rmse:23.87468	validation_1-rmse:27.86918
# [216]	validation_0-rmse:23.64289	validation_1-rmse:27.59501
# [217]	validation_0-rmse:23.41343	validation_1-rmse:27.32228
# [218]	validation_0-rmse:23.18627	validation_1-rmse:27.05055
# [219]	validation_0-rmse:22.96125	validation_1-rmse:26.78700
# [220]	validation_0-rmse:22.73868	validation_1-rmse:26.52274
# [221]	validation_0-rmse:22.51840	validation_1-rmse:26.25024
# [222]	validation_0-rmse:22.30031	validation_1-rmse:25.99242
# [223]	validation_0-rmse:22.08444	validation_1-rmse:25.73074
# [224]	validation_0-rmse:21.87054	validation_1-rmse:25.48039
# [225]	validation_0-rmse:21.65898	validation_1-rmse:25.23047
# [226]	validation_0-rmse:21.44962	validation_1-rmse:24.97248
# [227]	validation_0-rmse:21.24229	validation_1-rmse:24.72633
# [228]	validation_0-rmse:21.03691	validation_1-rmse:24.48782
# [229]	validation_0-rmse:20.83381	validation_1-rmse:24.24685
# [230]	validation_0-rmse:20.63277	validation_1-rmse:24.00956
# [231]	validation_0-rmse:20.43360	validation_1-rmse:23.77457
# [232]	validation_0-rmse:20.23657	validation_1-rmse:23.54162
# [233]	validation_0-rmse:20.04161	validation_1-rmse:23.30182
# [234]	validation_0-rmse:19.84855	validation_1-rmse:23.07347
# [235]	validation_0-rmse:19.65750	validation_1-rmse:22.84718
# [236]	validation_0-rmse:19.46836	validation_1-rmse:22.62135
# [237]	validation_0-rmse:19.28115	validation_1-rmse:22.40000
# [238]	validation_0-rmse:19.09591	validation_1-rmse:22.17119
# [239]	validation_0-rmse:18.91233	validation_1-rmse:21.95485
# [240]	validation_0-rmse:18.73078	validation_1-rmse:21.74028
# [241]	validation_0-rmse:18.55110	validation_1-rmse:21.52294
# [242]	validation_0-rmse:18.37325	validation_1-rmse:21.31243
# [243]	validation_0-rmse:18.19706	validation_1-rmse:21.10380
# [244]	validation_0-rmse:18.02284	validation_1-rmse:20.89025
# [245]	validation_0-rmse:17.85034	validation_1-rmse:20.68906
# [246]	validation_0-rmse:17.67962	validation_1-rmse:20.48998
# [247]	validation_0-rmse:17.51066	validation_1-rmse:20.28515
# [248]	validation_0-rmse:17.34342	validation_1-rmse:20.08724
# [249]	validation_0-rmse:17.17787	validation_1-rmse:19.88997
# [250]	validation_0-rmse:17.01395	validation_1-rmse:19.69953
# [251]	validation_0-rmse:16.85185	validation_1-rmse:19.50026
# [252]	validation_0-rmse:16.69134	validation_1-rmse:19.31113
# [253]	validation_0-rmse:16.53247	validation_1-rmse:19.12612
# [254]	validation_0-rmse:16.37529	validation_1-rmse:18.93432
# [255]	validation_0-rmse:16.21970	validation_1-rmse:18.75040
# [256]	validation_0-rmse:16.06555	validation_1-rmse:18.56830
# [257]	validation_0-rmse:15.91318	validation_1-rmse:18.38377
# [258]	validation_0-rmse:15.76230	validation_1-rmse:18.20833
# [259]	validation_0-rmse:15.61296	validation_1-rmse:18.02767
# [260]	validation_0-rmse:15.46519	validation_1-rmse:17.85594
# [261]	validation_0-rmse:15.31900	validation_1-rmse:17.67594
# [262]	validation_0-rmse:15.17412	validation_1-rmse:17.50501
# [263]	validation_0-rmse:15.03078	validation_1-rmse:17.33846
# [264]	validation_0-rmse:14.88903	validation_1-rmse:17.17172
# [265]	validation_0-rmse:14.74871	validation_1-rmse:17.00215
# [266]	validation_0-rmse:14.60972	validation_1-rmse:16.83923
# [267]	validation_0-rmse:14.47233	validation_1-rmse:16.67631
# [268]	validation_0-rmse:14.33640	validation_1-rmse:16.50876
# [269]	validation_0-rmse:14.20182	validation_1-rmse:16.35225
# [270]	validation_0-rmse:14.06860	validation_1-rmse:16.19331
# [271]	validation_0-rmse:13.93682	validation_1-rmse:16.04013
# [272]	validation_0-rmse:13.80643	validation_1-rmse:15.87976
# [273]	validation_0-rmse:13.67723	validation_1-rmse:15.72865
# [274]	validation_0-rmse:13.54951	validation_1-rmse:15.57755
# [275]	validation_0-rmse:13.42312	validation_1-rmse:15.43087
# [276]	validation_0-rmse:13.29806	validation_1-rmse:15.27971
# [277]	validation_0-rmse:13.17432	validation_1-rmse:15.13485
# [278]	validation_0-rmse:13.05180	validation_1-rmse:14.98732
# [279]	validation_0-rmse:12.93062	validation_1-rmse:14.84692
# [280]	validation_0-rmse:12.81069	validation_1-rmse:14.70505
# [281]	validation_0-rmse:12.69207	validation_1-rmse:14.56037
# [282]	validation_0-rmse:12.57465	validation_1-rmse:14.42452
# [283]	validation_0-rmse:12.45852	validation_1-rmse:14.28547
# [284]	validation_0-rmse:12.34360	validation_1-rmse:14.14572
# [285]	validation_0-rmse:12.22974	validation_1-rmse:14.01430
# [286]	validation_0-rmse:12.11722	validation_1-rmse:13.87632
# [287]	validation_0-rmse:12.00582	validation_1-rmse:13.74563
# [288]	validation_0-rmse:11.89569	validation_1-rmse:13.61399
# [289]	validation_0-rmse:11.78661	validation_1-rmse:13.48615
# [290]	validation_0-rmse:11.67858	validation_1-rmse:13.35669
# [291]	validation_0-rmse:11.57184	validation_1-rmse:13.23270
# [292]	validation_0-rmse:11.46627	validation_1-rmse:13.10357
# [293]	validation_0-rmse:11.36179	validation_1-rmse:12.98234
# [294]	validation_0-rmse:11.25847	validation_1-rmse:12.85931
# [295]	validation_0-rmse:11.15619	validation_1-rmse:12.74216
# [296]	validation_0-rmse:11.05493	validation_1-rmse:12.61992
# [297]	validation_0-rmse:10.95465	validation_1-rmse:12.50013
# [298]	validation_0-rmse:10.85568	validation_1-rmse:12.38688
# [299]	validation_0-rmse:10.75774	validation_1-rmse:12.26932
# [300]	validation_0-rmse:10.66088	validation_1-rmse:12.15859
# [301]	validation_0-rmse:10.56499	validation_1-rmse:12.04784
# [302]	validation_0-rmse:10.46997	validation_1-rmse:11.93396
# [303]	validation_0-rmse:10.37618	validation_1-rmse:11.82261
# [304]	validation_0-rmse:10.28340	validation_1-rmse:11.71676
# [305]	validation_0-rmse:10.19161	validation_1-rmse:11.60476
# [306]	validation_0-rmse:10.10083	validation_1-rmse:11.50131
# [307]	validation_0-rmse:10.01089	validation_1-rmse:11.39331
# [308]	validation_0-rmse:9.92186	validation_1-rmse:11.28934
# [309]	validation_0-rmse:9.83400	validation_1-rmse:11.18939
# [310]	validation_0-rmse:9.74705	validation_1-rmse:11.08399
# [311]	validation_0-rmse:9.66110	validation_1-rmse:10.98528
# [312]	validation_0-rmse:9.57610	validation_1-rmse:10.88485
# [313]	validation_0-rmse:9.49200	validation_1-rmse:10.79019
# [314]	validation_0-rmse:9.40875	validation_1-rmse:10.68981
# [315]	validation_0-rmse:9.32630	validation_1-rmse:10.59733
# [316]	validation_0-rmse:9.24468	validation_1-rmse:10.50024
# [317]	validation_0-rmse:9.16415	validation_1-rmse:10.40325
# [318]	validation_0-rmse:9.08458	validation_1-rmse:10.31398
# [319]	validation_0-rmse:9.00590	validation_1-rmse:10.22048
# [320]	validation_0-rmse:8.92807	validation_1-rmse:10.13267
# [321]	validation_0-rmse:8.85095	validation_1-rmse:10.04083
# [322]	validation_0-rmse:8.77479	validation_1-rmse:9.95508
# [323]	validation_0-rmse:8.69912	validation_1-rmse:9.86560
# [324]	validation_0-rmse:8.62466	validation_1-rmse:9.78096
# [325]	validation_0-rmse:8.55100	validation_1-rmse:9.69779
# [326]	validation_0-rmse:8.47815	validation_1-rmse:9.61235
# [327]	validation_0-rmse:8.40595	validation_1-rmse:9.53211
# [328]	validation_0-rmse:8.33455	validation_1-rmse:9.45299
# [329]	validation_0-rmse:8.26412	validation_1-rmse:9.36868
# [330]	validation_0-rmse:8.19422	validation_1-rmse:9.28607
# [331]	validation_0-rmse:8.12505	validation_1-rmse:9.20688
# [332]	validation_0-rmse:8.05685	validation_1-rmse:9.12621
# [333]	validation_0-rmse:7.98911	validation_1-rmse:9.04966
# [334]	validation_0-rmse:7.92253	validation_1-rmse:8.97527
# [335]	validation_0-rmse:7.85643	validation_1-rmse:8.89789
# [336]	validation_0-rmse:7.79113	validation_1-rmse:8.82146
# [337]	validation_0-rmse:7.72678	validation_1-rmse:8.75003
# [338]	validation_0-rmse:7.66310	validation_1-rmse:8.67981
# [339]	validation_0-rmse:7.59977	validation_1-rmse:8.60885
# [340]	validation_0-rmse:7.53734	validation_1-rmse:8.53809
# [341]	validation_0-rmse:7.47585	validation_1-rmse:8.46993
# [342]	validation_0-rmse:7.41517	validation_1-rmse:8.39947
# [343]	validation_0-rmse:7.35502	validation_1-rmse:8.33386
# [344]	validation_0-rmse:7.29563	validation_1-rmse:8.26827
# [345]	validation_0-rmse:7.23659	validation_1-rmse:8.20363
# [346]	validation_0-rmse:7.17848	validation_1-rmse:8.13789
# [347]	validation_0-rmse:7.12082	validation_1-rmse:8.07493
# [348]	validation_0-rmse:7.06387	validation_1-rmse:8.01037
# [349]	validation_0-rmse:7.00752	validation_1-rmse:7.94907
# [350]	validation_0-rmse:6.95191	validation_1-rmse:7.88917
# [351]	validation_0-rmse:6.89690	validation_1-rmse:7.82951
# [352]	validation_0-rmse:6.84238	validation_1-rmse:7.76708
# [353]	validation_0-rmse:6.78883	validation_1-rmse:7.70607
# [354]	validation_0-rmse:6.73565	validation_1-rmse:7.64633
# [355]	validation_0-rmse:6.68312	validation_1-rmse:7.58985
# [356]	validation_0-rmse:6.63132	validation_1-rmse:7.53206
# [357]	validation_0-rmse:6.57970	validation_1-rmse:7.47389
# [358]	validation_0-rmse:6.52898	validation_1-rmse:7.41972
# [359]	validation_0-rmse:6.47885	validation_1-rmse:7.36629
# [360]	validation_0-rmse:6.42924	validation_1-rmse:7.30999
# [361]	validation_0-rmse:6.38045	validation_1-rmse:7.25573
# [362]	validation_0-rmse:6.33224	validation_1-rmse:7.20375
# [363]	validation_0-rmse:6.28450	validation_1-rmse:7.15210
# [364]	validation_0-rmse:6.23742	validation_1-rmse:7.10157
# [365]	validation_0-rmse:6.19093	validation_1-rmse:7.04980
# [366]	validation_0-rmse:6.14497	validation_1-rmse:7.00071
# [367]	validation_0-rmse:6.09927	validation_1-rmse:6.95092
# [368]	validation_0-rmse:6.05441	validation_1-rmse:6.90328
# [369]	validation_0-rmse:6.01010	validation_1-rmse:6.85623
# [370]	validation_0-rmse:5.96584	validation_1-rmse:6.80788
# [371]	validation_0-rmse:5.92248	validation_1-rmse:6.76106
# [372]	validation_0-rmse:5.87964	validation_1-rmse:6.71605
# [373]	validation_0-rmse:5.83703	validation_1-rmse:6.67035
# [374]	validation_0-rmse:5.79514	validation_1-rmse:6.62663
# [375]	validation_0-rmse:5.75365	validation_1-rmse:6.58231
# [376]	validation_0-rmse:5.71269	validation_1-rmse:6.53991
# [377]	validation_0-rmse:5.67233	validation_1-rmse:6.49813
# [378]	validation_0-rmse:5.63264	validation_1-rmse:6.45691
# [379]	validation_0-rmse:5.59313	validation_1-rmse:6.41381
# [380]	validation_0-rmse:5.55426	validation_1-rmse:6.37392
# [381]	validation_0-rmse:5.51586	validation_1-rmse:6.33393
# [382]	validation_0-rmse:5.47770	validation_1-rmse:6.29230
# [383]	validation_0-rmse:5.44024	validation_1-rmse:6.25355
# [384]	validation_0-rmse:5.40310	validation_1-rmse:6.21561
# [385]	validation_0-rmse:5.36654	validation_1-rmse:6.17874
# [386]	validation_0-rmse:5.33008	validation_1-rmse:6.14279
# [387]	validation_0-rmse:5.29443	validation_1-rmse:6.10686
# [388]	validation_0-rmse:5.25900	validation_1-rmse:6.07147
# [389]	validation_0-rmse:5.22394	validation_1-rmse:6.03717
# [390]	validation_0-rmse:5.18961	validation_1-rmse:6.00311
# [391]	validation_0-rmse:5.15570	validation_1-rmse:5.96961
# [392]	validation_0-rmse:5.12208	validation_1-rmse:5.93868
# [393]	validation_0-rmse:5.08881	validation_1-rmse:5.90600
# [394]	validation_0-rmse:5.05591	validation_1-rmse:5.87383
# [395]	validation_0-rmse:5.02337	validation_1-rmse:5.84282
# [396]	validation_0-rmse:4.99157	validation_1-rmse:5.81166
# [397]	validation_0-rmse:4.96013	validation_1-rmse:5.78136
# [398]	validation_0-rmse:4.92850	validation_1-rmse:5.75112
# [399]	validation_0-rmse:4.89771	validation_1-rmse:5.72142
# [400]	validation_0-rmse:4.86696	validation_1-rmse:5.69104
# [401]	validation_0-rmse:4.83693	validation_1-rmse:5.66117
# [402]	validation_0-rmse:4.80665	validation_1-rmse:5.63592
# [403]	validation_0-rmse:4.77710	validation_1-rmse:5.60704
# [404]	validation_0-rmse:4.74811	validation_1-rmse:5.57778
# [405]	validation_0-rmse:4.71911	validation_1-rmse:5.55125
# [406]	validation_0-rmse:4.69122	validation_1-rmse:5.52411
# [407]	validation_0-rmse:4.66258	validation_1-rmse:5.50119
# [408]	validation_0-rmse:4.63511	validation_1-rmse:5.47496
# [409]	validation_0-rmse:4.60755	validation_1-rmse:5.44969
# [410]	validation_0-rmse:4.58081	validation_1-rmse:5.42323
# [411]	validation_0-rmse:4.55355	validation_1-rmse:5.40214
# [412]	validation_0-rmse:4.52739	validation_1-rmse:5.37716
# [413]	validation_0-rmse:4.50164	validation_1-rmse:5.35314
# [414]	validation_0-rmse:4.47597	validation_1-rmse:5.32846
# [415]	validation_0-rmse:4.45040	validation_1-rmse:5.30633
# [416]	validation_0-rmse:4.42539	validation_1-rmse:5.28252
# [417]	validation_0-rmse:4.40011	validation_1-rmse:5.26512
# [418]	validation_0-rmse:4.37570	validation_1-rmse:5.24215
# [419]	validation_0-rmse:4.35150	validation_1-rmse:5.22168
# [420]	validation_0-rmse:4.32762	validation_1-rmse:5.20156
# [421]	validation_0-rmse:4.30419	validation_1-rmse:5.17990
# [422]	validation_0-rmse:4.28053	validation_1-rmse:5.16500
# [423]	validation_0-rmse:4.25750	validation_1-rmse:5.14452
# [424]	validation_0-rmse:4.23481	validation_1-rmse:5.12588
# [425]	validation_0-rmse:4.21239	validation_1-rmse:5.10903
# [426]	validation_0-rmse:4.19014	validation_1-rmse:5.08965
# [427]	validation_0-rmse:4.16841	validation_1-rmse:5.07234
# [428]	validation_0-rmse:4.14682	validation_1-rmse:5.05895
# [429]	validation_0-rmse:4.12544	validation_1-rmse:5.04491
# [430]	validation_0-rmse:4.10434	validation_1-rmse:5.02696
# [431]	validation_0-rmse:4.08328	validation_1-rmse:5.00887
# [432]	validation_0-rmse:4.06283	validation_1-rmse:4.99681
# [433]	validation_0-rmse:4.04233	validation_1-rmse:4.98595
# [434]	validation_0-rmse:4.02253	validation_1-rmse:4.96964
# [435]	validation_0-rmse:4.00294	validation_1-rmse:4.95365
# [436]	validation_0-rmse:3.98396	validation_1-rmse:4.93806
# [437]	validation_0-rmse:3.96476	validation_1-rmse:4.92566
# [438]	validation_0-rmse:3.94551	validation_1-rmse:4.91022
# [439]	validation_0-rmse:3.92701	validation_1-rmse:4.89534
# [440]	validation_0-rmse:3.90871	validation_1-rmse:4.88583
# [441]	validation_0-rmse:3.89046	validation_1-rmse:4.87132
# [442]	validation_0-rmse:3.87240	validation_1-rmse:4.85651
# [443]	validation_0-rmse:3.85507	validation_1-rmse:4.84172
# [444]	validation_0-rmse:3.83719	validation_1-rmse:4.83254
# [445]	validation_0-rmse:3.82027	validation_1-rmse:4.81836
# [446]	validation_0-rmse:3.80336	validation_1-rmse:4.81058
# [447]	validation_0-rmse:3.78676	validation_1-rmse:4.80051
# [448]	validation_0-rmse:3.77023	validation_1-rmse:4.78741
# [449]	validation_0-rmse:3.75421	validation_1-rmse:4.77437
# [450]	validation_0-rmse:3.73786	validation_1-rmse:4.76629
# [451]	validation_0-rmse:3.72174	validation_1-rmse:4.75518
# [452]	validation_0-rmse:3.70614	validation_1-rmse:4.74315
# [453]	validation_0-rmse:3.69088	validation_1-rmse:4.73117
# [454]	validation_0-rmse:3.67590	validation_1-rmse:4.71976
# [455]	validation_0-rmse:3.66098	validation_1-rmse:4.70859
# [456]	validation_0-rmse:3.64595	validation_1-rmse:4.69857
# [457]	validation_0-rmse:3.63127	validation_1-rmse:4.68780
# [458]	validation_0-rmse:3.61716	validation_1-rmse:4.67735
# [459]	validation_0-rmse:3.60298	validation_1-rmse:4.66716
# [460]	validation_0-rmse:3.58909	validation_1-rmse:4.65718
# [461]	validation_0-rmse:3.57517	validation_1-rmse:4.65312
# [462]	validation_0-rmse:3.56170	validation_1-rmse:4.64358
# [463]	validation_0-rmse:3.54805	validation_1-rmse:4.63517
# [464]	validation_0-rmse:3.53517	validation_1-rmse:4.62608
# [465]	validation_0-rmse:3.52208	validation_1-rmse:4.62180
# [466]	validation_0-rmse:3.50868	validation_1-rmse:4.61425
# [467]	validation_0-rmse:3.49595	validation_1-rmse:4.61025
# [468]	validation_0-rmse:3.48354	validation_1-rmse:4.60187
# [469]	validation_0-rmse:3.47122	validation_1-rmse:4.59370
# [470]	validation_0-rmse:3.45885	validation_1-rmse:4.58660
# [471]	validation_0-rmse:3.44654	validation_1-rmse:4.57961
# [472]	validation_0-rmse:3.43461	validation_1-rmse:4.57196
# [473]	validation_0-rmse:3.42284	validation_1-rmse:4.56509
# [474]	validation_0-rmse:3.41089	validation_1-rmse:4.55862
# [475]	validation_0-rmse:3.39875	validation_1-rmse:4.55232
# [476]	validation_0-rmse:3.38758	validation_1-rmse:4.54513
# [477]	validation_0-rmse:3.37628	validation_1-rmse:4.53887
# [478]	validation_0-rmse:3.36452	validation_1-rmse:4.53301
# [479]	validation_0-rmse:3.35367	validation_1-rmse:4.52712
# [480]	validation_0-rmse:3.34289	validation_1-rmse:4.52072
# [481]	validation_0-rmse:3.33250	validation_1-rmse:4.51433
# [482]	validation_0-rmse:3.32200	validation_1-rmse:4.50878
# [483]	validation_0-rmse:3.31198	validation_1-rmse:4.50344
# [484]	validation_0-rmse:3.30157	validation_1-rmse:4.49854
# [485]	validation_0-rmse:3.29120	validation_1-rmse:4.49342
# [486]	validation_0-rmse:3.28153	validation_1-rmse:4.48871
# [487]	validation_0-rmse:3.27162	validation_1-rmse:4.48387
# [488]	validation_0-rmse:3.26212	validation_1-rmse:4.47850
# [489]	validation_0-rmse:3.25291	validation_1-rmse:4.47388
# [490]	validation_0-rmse:3.24382	validation_1-rmse:4.46878
# [491]	validation_0-rmse:3.23428	validation_1-rmse:4.46566
# [492]	validation_0-rmse:3.22570	validation_1-rmse:4.46089
# [493]	validation_0-rmse:3.21664	validation_1-rmse:4.45650
# [494]	validation_0-rmse:3.20749	validation_1-rmse:4.45369
# [495]	validation_0-rmse:3.19892	validation_1-rmse:4.44955
# [496]	validation_0-rmse:3.19003	validation_1-rmse:4.44694
# [497]	validation_0-rmse:3.18110	validation_1-rmse:4.44442
# [498]	validation_0-rmse:3.17271	validation_1-rmse:4.44059
# [499]	validation_0-rmse:3.16401	validation_1-rmse:4.43825
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# We'll now see how the RMSE-score looks like:

# %%
y_pred = xgb.predict(X_test)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 4.438250975557941

# %% [markdown]
# Let's also make a graph to visualize the output

# %%
train,test=split(close_df,date)
test['prediction'] = xgb.predict(X_test)
test['prediction'] = xgb.predict(X_test)
df = close_df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df.tail(20)[['MSFT']].plot(figsize=(15, 5)) #month
df.tail(20)['prediction'].plot(ax=ax)
plt.legend(['Real stock price', 'Predicted value'])
ax.set_title('Predicted values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 train,test=split(close_df,date)
# ----> 2 test['prediction'] = xgb.predict(X_test)
#       3 test['prediction'] = xgb.predict(X_test)
#       4 df = close_df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (21) does not match length of index (5)

# %% [markdown]
# We are happy with this result. Hence we can finalize the model by using all the data

# %%
#Finalization
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=500, early_stopping_rounds=50, learning_rate=0.01, max_depth=7)
xgb.fit(X, y, eval_set=[(X, y)], verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# We can now make a prediction for the 5 coming days:

# %%
def predict_head(X):
    """
    CAREFUL!!
    This function will only predict the future 5 business days 
    as from January 1st, 2023.  
    """
    date_list = [pd.to_datetime('2023-01-03'), pd.to_datetime('2023-01-04'), pd.to_datetime('2023-01-05'), pd.to_datetime('2023-01-06'), pd.to_datetime('2023-01-09')]
    start_values = {'t-1': xgb.predict(X.iloc[-1:])[0], 't-2': X.iloc[-1,0]}

    # Loop over the next five days
    for day in date_list:
        values = {'t-1': xgb.predict(X.iloc[-1:])[0], 't-2': X.iloc[-1,0]}
        X = X.append(pd.DataFrame(values, index=[day]))
    
    y_predict=xgb.predict(X.tail())
    return y_predict

y_predict=predict_head(X)

# %% [markdown]
# We can now also compare with the actual values:

# %%
stock_list = ['MSFT', 'MMC', 'NI', 'BAX', 'CNP', 'TGT', 'JPM', 'BA']
close_df=get_data("20230101","20230110",stock_list)
future=close_df[['MSFT']]
future['predicted']=y_predict
future
# Out:
#                   MSFT   predicted
# Date
# 2023-01-03  238.981430  239.348328
# 2023-01-04  228.527618  239.012451
# 2023-01-05  221.754562  238.474243
# 2023-01-06  224.368011  238.504074
# 2023-01-09  226.552551  238.485367

# %% [markdown]
# Save the model

# %%
xgb.save_model("./model/xgbmodel.bin")
