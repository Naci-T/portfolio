# %%
# Import libraries
from datetime import datetime
import yfinance as yf
import pandas as pd 
from pandas_datareader import data as web
import numpy as np 
from pypfopt.efficient_frontier import EfficientFrontier 
from pypfopt import risk_models
from pypfopt import expected_returns
import seaborn as sns
import matplotlib.pyplot as plt

from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
def get_data(startdate, enddate, stocklist): 
    """
    * This function retrieves the Adjusted close price from the historical data 
      for each stock in the list, for the given date range.
    * Enter dates as "yyyymmdd". 
    """
    start_date=datetime.strptime(startdate, '%Y%m%d').date()
    end_date=datetime.strptime(enddate, '%Y%m%d').date()
    data = yf.download(stocklist, start=start_date, end=end_date, progress=False)
    return data['Adj Close'].copy()

# %%
def split(df,date): 
    """This function divides the dataframe in a train
    and test test splitted by the date given.
    """
    train=df.loc[df.index<date]
    test=df.loc[df.index>=date]
    return train, test

# %%
def plot_close(df, date):
    """
    In this function you can enter a date as 'yyyymmdd' and 
    see the plot of train and test  
    """
    train,test= split(df,date)

    fig, ax = plt.subplots(figsize=(20, 5))
    train.plot(ax=ax, label='Training', title='Adjusted Closing Prices')
    test.plot(ax=ax, label='Test Set')
    ax.axvline(date, color='black', ls='--')
    ax.legend(['Training', 'Test'])
    plt.show()

# %%
def prepare_data(df, date):
    # Add lag to the DataFrame
    df_lagged = df.copy()
    df_lagged['t-1'] = df_lagged['MSFT'].shift(1)
    df_lagged['t-2'] = df_lagged['MSFT'].shift(2)
    df_lagged.dropna(inplace=True)
    
    # Split the DataFrame into train and test sets
    train,test= split(df_lagged,date)
    
    # Split the train and test sets into features and target
    X_train = train[['t-1', 't-2']]
    y_train = train['MSFT']
    X_test = test[['t-1', 't-2']]
    y_test = test['MSFT']
    
    # Combine train and test sets into X and y
    X = df_lagged[['t-1', 't-2']]
    y = df_lagged['MSFT']
    
    return X_train, X_test, y_train, y_test, X, y

# %% [markdown]
# We will now use the functions that we have defined.

# %%
#We will make a prediction with MSFT 

stock_list = ['MSFT', 'MMC', 'NI', 'BAX', 'CNP', 'TGT', 'JPM', 'BA']
close_df=get_data("20180101","20230101",stock_list)
close_df=close_df[['MSFT']]
close_df.head()

# We will split the data in train and test set and plot the stock price
date="20221201"
plot_close(close_df, date)

# %%
#Store all the values
X_train, X_test, y_train, y_test, X, y=prepare_data(close_df, date)

# %% [markdown]
# We'll try to fit a model but use a gridsearch in order to find the best parameters.

# %%
model = XGBRegressor()
model.fit(X_train, y_train)

param_grid = {
    
    'n_estimators': [100, 500, 1000],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.3]
}

grid_search = GridSearchCV(model, param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# Let's use this model and add early stopping in order to avoid overfitting:

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=500, early_stopping_rounds=50, learning_rate=0.01, max_depth=7)
xgb.fit(X_train, y_train, eval_set=[(X_train, y_train),(X_test,y_test)], verbose=True)
# Out:
# [0]	validation_0-rmse:200.96116	validation_1-rmse:242.22974
# [1]	validation_0-rmse:198.96944	validation_1-rmse:239.86210
# [2]	validation_0-rmse:196.99737	validation_1-rmse:237.50959
# [3]	validation_0-rmse:195.04445	validation_1-rmse:235.16242
# [4]	validation_0-rmse:193.11106	validation_1-rmse:232.83862
# [5]	validation_0-rmse:191.19672	validation_1-rmse:230.53070
# [6]	validation_0-rmse:189.30207	validation_1-rmse:228.28367
# [7]	validation_0-rmse:187.42565	validation_1-rmse:226.02246
# [8]	validation_0-rmse:185.56853	validation_1-rmse:223.82019
# [9]	validation_0-rmse:183.72933	validation_1-rmse:221.60320
# [10]	validation_0-rmse:181.90884	validation_1-rmse:219.39898
# [11]	validation_0-rmse:180.10610	validation_1-rmse:217.21355
# [12]	validation_0-rmse:178.32146	validation_1-rmse:215.05332
# [13]	validation_0-rmse:176.55495	validation_1-rmse:212.95909
# [14]	validation_0-rmse:174.80565	validation_1-rmse:210.84177
# [15]	validation_0-rmse:173.07349	validation_1-rmse:208.72371
# [16]	validation_0-rmse:171.35879	validation_1-rmse:206.64684
# [17]	validation_0-rmse:169.66096	validation_1-rmse:204.57084
# [18]	validation_0-rmse:167.98011	validation_1-rmse:202.54434
# [19]	validation_0-rmse:166.31588	validation_1-rmse:200.50872
# [20]	validation_0-rmse:164.66830	validation_1-rmse:198.52250
# [21]	validation_0-rmse:163.03705	validation_1-rmse:196.53004
# [22]	validation_0-rmse:161.42201	validation_1-rmse:194.58011
# [23]	validation_0-rmse:159.82304	validation_1-rmse:192.62710
# [24]	validation_0-rmse:158.24004	validation_1-rmse:190.70700
# [25]	validation_0-rmse:156.67267	validation_1-rmse:188.81410
# [26]	validation_0-rmse:155.12095	validation_1-rmse:186.94366
# [27]	validation_0-rmse:153.58463	validation_1-rmse:185.07775
# [28]	validation_0-rmse:152.06354	validation_1-rmse:183.21686
# [29]	validation_0-rmse:150.55758	validation_1-rmse:181.39849
# [30]	validation_0-rmse:149.06659	validation_1-rmse:179.57471
# [31]	validation_0-rmse:147.59039	validation_1-rmse:177.82596
# [32]	validation_0-rmse:146.12893	validation_1-rmse:176.03824
# [33]	validation_0-rmse:144.68201	validation_1-rmse:174.26832
# [34]	validation_0-rmse:143.24935	validation_1-rmse:172.53447
# [35]	validation_0-rmse:141.83097	validation_1-rmse:170.81965
# [36]	validation_0-rmse:140.42666	validation_1-rmse:169.12612
# [37]	validation_0-rmse:139.03634	validation_1-rmse:167.42561
# [38]	validation_0-rmse:137.65981	validation_1-rmse:165.75992
# [39]	validation_0-rmse:136.29694	validation_1-rmse:164.09318
# [40]	validation_0-rmse:134.94771	validation_1-rmse:162.47430
# [41]	validation_0-rmse:133.61171	validation_1-rmse:160.86928
# [42]	validation_0-rmse:132.28889	validation_1-rmse:159.24610
# [43]	validation_0-rmse:130.97930	validation_1-rmse:157.65957
# [44]	validation_0-rmse:129.68268	validation_1-rmse:156.06883
# [45]	validation_0-rmse:128.39896	validation_1-rmse:154.54942
# [46]	validation_0-rmse:127.12798	validation_1-rmse:152.99027
# [47]	validation_0-rmse:125.86963	validation_1-rmse:151.46951
# [48]	validation_0-rmse:124.62344	validation_1-rmse:149.96548
# [49]	validation_0-rmse:123.38988	validation_1-rmse:148.45234
# [50]	validation_0-rmse:122.16825	validation_1-rmse:146.96978
# [51]	validation_0-rmse:120.95904	validation_1-rmse:145.48678
# [52]	validation_0-rmse:119.76156	validation_1-rmse:144.03699
# [53]	validation_0-rmse:118.57626	validation_1-rmse:142.58362
# [54]	validation_0-rmse:117.40276	validation_1-rmse:141.18622
# [55]	validation_0-rmse:116.24058	validation_1-rmse:139.78749
# [56]	validation_0-rmse:115.09013	validation_1-rmse:138.37706
# [57]	validation_0-rmse:113.95121	validation_1-rmse:136.98078
# [58]	validation_0-rmse:112.82329	validation_1-rmse:135.62507
# [59]	validation_0-rmse:111.70676	validation_1-rmse:134.25798
# [60]	validation_0-rmse:110.60102	validation_1-rmse:132.93504
# [61]	validation_0-rmse:109.50654	validation_1-rmse:131.59503
# [62]	validation_0-rmse:108.42265	validation_1-rmse:130.28503
# [63]	validation_0-rmse:107.34984	validation_1-rmse:128.97013
# [64]	validation_0-rmse:106.28752	validation_1-rmse:127.68967
# [65]	validation_0-rmse:105.23585	validation_1-rmse:126.40249
# [66]	validation_0-rmse:104.19472	validation_1-rmse:125.12428
# [67]	validation_0-rmse:103.16354	validation_1-rmse:123.87869
# [68]	validation_0-rmse:102.14288	validation_1-rmse:122.62963
# [69]	validation_0-rmse:101.13207	validation_1-rmse:121.41566
# [70]	validation_0-rmse:100.13158	validation_1-rmse:120.18764
# [71]	validation_0-rmse:99.14071	validation_1-rmse:118.99046
# [72]	validation_0-rmse:98.16003	validation_1-rmse:117.79049
# [73]	validation_0-rmse:97.18878	validation_1-rmse:116.61045
# [74]	validation_0-rmse:96.22748	validation_1-rmse:115.44493
# [75]	validation_0-rmse:95.27537	validation_1-rmse:114.30038
# [76]	validation_0-rmse:94.33280	validation_1-rmse:113.14750
# [77]	validation_0-rmse:93.39962	validation_1-rmse:112.01126
# [78]	validation_0-rmse:92.47549	validation_1-rmse:110.90032
# [79]	validation_0-rmse:91.56095	validation_1-rmse:109.78010
# [80]	validation_0-rmse:90.65551	validation_1-rmse:108.68666
# [81]	validation_0-rmse:89.75869	validation_1-rmse:107.60403
# [82]	validation_0-rmse:88.87092	validation_1-rmse:106.51841
# [83]	validation_0-rmse:87.99178	validation_1-rmse:105.46184
# [84]	validation_0-rmse:87.12156	validation_1-rmse:104.39682
# [85]	validation_0-rmse:86.25997	validation_1-rmse:103.35231
# [86]	validation_0-rmse:85.40712	validation_1-rmse:102.30528
# [87]	validation_0-rmse:84.56237	validation_1-rmse:101.29006
# [88]	validation_0-rmse:83.72639	validation_1-rmse:100.27756
# [89]	validation_0-rmse:82.89841	validation_1-rmse:99.28153
# [90]	validation_0-rmse:82.07876	validation_1-rmse:98.27864
# [91]	validation_0-rmse:81.26714	validation_1-rmse:97.29500
# [92]	validation_0-rmse:80.46358	validation_1-rmse:96.30478
# [93]	validation_0-rmse:79.66817	validation_1-rmse:95.32445
# [94]	validation_0-rmse:78.88065	validation_1-rmse:94.38777
# [95]	validation_0-rmse:78.10071	validation_1-rmse:93.45112
# [96]	validation_0-rmse:77.32863	validation_1-rmse:92.49991
# [97]	validation_0-rmse:76.56412	validation_1-rmse:91.59666
# [98]	validation_0-rmse:75.80717	validation_1-rmse:90.66979
# [99]	validation_0-rmse:75.05774	validation_1-rmse:89.75218
# [100]	validation_0-rmse:74.31609	validation_1-rmse:88.85435
# [101]	validation_0-rmse:73.58150	validation_1-rmse:87.96915
# [102]	validation_0-rmse:72.85417	validation_1-rmse:87.07877
# [103]	validation_0-rmse:72.13408	validation_1-rmse:86.19704
# [104]	validation_0-rmse:71.42115	validation_1-rmse:85.35962
# [105]	validation_0-rmse:70.71528	validation_1-rmse:84.49479
# [106]	validation_0-rmse:70.01645	validation_1-rmse:83.63925
# [107]	validation_0-rmse:69.32484	validation_1-rmse:82.80215
# [108]	validation_0-rmse:68.63985	validation_1-rmse:81.98359
# [109]	validation_0-rmse:67.96161	validation_1-rmse:81.15187
# [110]	validation_0-rmse:67.29021	validation_1-rmse:80.35860
# [111]	validation_0-rmse:66.62540	validation_1-rmse:79.54348
# [112]	validation_0-rmse:65.96720	validation_1-rmse:78.73713
# [113]	validation_0-rmse:65.31557	validation_1-rmse:77.95005
# [114]	validation_0-rmse:64.67040	validation_1-rmse:77.15922
# [115]	validation_0-rmse:64.03187	validation_1-rmse:76.38672
# [116]	validation_0-rmse:63.39945	validation_1-rmse:75.60714
# [117]	validation_0-rmse:62.77333	validation_1-rmse:74.85131
# [118]	validation_0-rmse:62.15344	validation_1-rmse:74.09167
# [119]	validation_0-rmse:61.53984	validation_1-rmse:73.35903
# [120]	validation_0-rmse:60.93219	validation_1-rmse:72.61451
# [121]	validation_0-rmse:60.33051	validation_1-rmse:71.88796
# [122]	validation_0-rmse:59.73493	validation_1-rmse:71.15512
# [123]	validation_0-rmse:59.14520	validation_1-rmse:70.46273
# [124]	validation_0-rmse:58.56138	validation_1-rmse:69.74985
# [125]	validation_0-rmse:57.98335	validation_1-rmse:69.04270
# [126]	validation_0-rmse:57.41116	validation_1-rmse:68.34408
# [127]	validation_0-rmse:56.84458	validation_1-rmse:67.65095
# [128]	validation_0-rmse:56.28365	validation_1-rmse:66.95997
# [129]	validation_0-rmse:55.72835	validation_1-rmse:66.30048
# [130]	validation_0-rmse:55.17855	validation_1-rmse:65.62795
# [131]	validation_0-rmse:54.63411	validation_1-rmse:64.98058
# [132]	validation_0-rmse:54.09527	validation_1-rmse:64.32257
# [133]	validation_0-rmse:53.56162	validation_1-rmse:63.69676
# [134]	validation_0-rmse:53.03322	validation_1-rmse:63.05892
# [135]	validation_0-rmse:52.51022	validation_1-rmse:62.41442
# [136]	validation_0-rmse:51.99229	validation_1-rmse:61.78923
# [137]	validation_0-rmse:51.47973	validation_1-rmse:61.16628
# [138]	validation_0-rmse:50.97206	validation_1-rmse:60.55349
# [139]	validation_0-rmse:50.46946	validation_1-rmse:59.94684
# [140]	validation_0-rmse:49.97187	validation_1-rmse:59.34702
# [141]	validation_0-rmse:49.47923	validation_1-rmse:58.75250
# [142]	validation_0-rmse:48.99162	validation_1-rmse:58.15698
# [143]	validation_0-rmse:48.50874	validation_1-rmse:57.57429
# [144]	validation_0-rmse:48.03069	validation_1-rmse:56.99743
# [145]	validation_0-rmse:47.55741	validation_1-rmse:56.42634
# [146]	validation_0-rmse:47.08895	validation_1-rmse:55.85791
# [147]	validation_0-rmse:46.62502	validation_1-rmse:55.30866
# [148]	validation_0-rmse:46.16572	validation_1-rmse:54.75453
# [149]	validation_0-rmse:45.71102	validation_1-rmse:54.20596
# [150]	validation_0-rmse:45.26096	validation_1-rmse:53.65898
# [151]	validation_0-rmse:44.81517	validation_1-rmse:53.12971
# [152]	validation_0-rmse:44.37391	validation_1-rmse:52.59750
# [153]	validation_0-rmse:43.93707	validation_1-rmse:52.07061
# [154]	validation_0-rmse:43.50456	validation_1-rmse:51.55735
# [155]	validation_0-rmse:43.07636	validation_1-rmse:51.03317
# [156]	validation_0-rmse:42.65245	validation_1-rmse:50.52197
# [157]	validation_0-rmse:42.23283	validation_1-rmse:50.01294
# [158]	validation_0-rmse:41.81722	validation_1-rmse:49.52719
# [159]	validation_0-rmse:41.40586	validation_1-rmse:49.03118
# [160]	validation_0-rmse:40.99861	validation_1-rmse:48.53049
# [161]	validation_0-rmse:40.59530	validation_1-rmse:48.05233
# [162]	validation_0-rmse:40.19611	validation_1-rmse:47.56476
# [163]	validation_0-rmse:39.80093	validation_1-rmse:47.08837
# [164]	validation_0-rmse:39.40967	validation_1-rmse:46.60758
# [165]	validation_0-rmse:39.02235	validation_1-rmse:46.14070
# [166]	validation_0-rmse:38.63882	validation_1-rmse:45.68343
# [167]	validation_0-rmse:38.25916	validation_1-rmse:45.21535
# [168]	validation_0-rmse:37.88328	validation_1-rmse:44.75823
# [169]	validation_0-rmse:37.51112	validation_1-rmse:44.30513
# [170]	validation_0-rmse:37.14269	validation_1-rmse:43.85660
# [171]	validation_0-rmse:36.77797	validation_1-rmse:43.41123
# [172]	validation_0-rmse:36.41686	validation_1-rmse:42.97168
# [173]	validation_0-rmse:36.05940	validation_1-rmse:42.53520
# [174]	validation_0-rmse:35.70539	validation_1-rmse:42.11674
# [175]	validation_0-rmse:35.35499	validation_1-rmse:41.69099
# [176]	validation_0-rmse:35.00815	validation_1-rmse:41.26755
# [177]	validation_0-rmse:34.66472	validation_1-rmse:40.84969
# [178]	validation_0-rmse:34.32478	validation_1-rmse:40.42913
# [179]	validation_0-rmse:33.98819	validation_1-rmse:40.01963
# [180]	validation_0-rmse:33.65502	validation_1-rmse:39.61317
# [181]	validation_0-rmse:33.32512	validation_1-rmse:39.21251
# [182]	validation_0-rmse:32.99858	validation_1-rmse:38.80921
# [183]	validation_0-rmse:32.67527	validation_1-rmse:38.42740
# [184]	validation_0-rmse:32.35522	validation_1-rmse:38.03672
# [185]	validation_0-rmse:32.03823	validation_1-rmse:37.66222
# [186]	validation_0-rmse:31.72453	validation_1-rmse:37.28074
# [187]	validation_0-rmse:31.41401	validation_1-rmse:36.90176
# [188]	validation_0-rmse:31.10654	validation_1-rmse:36.53884
# [189]	validation_0-rmse:30.80221	validation_1-rmse:36.16304
# [190]	validation_0-rmse:30.50090	validation_1-rmse:35.80743
# [191]	validation_0-rmse:30.20254	validation_1-rmse:35.45418
# [192]	validation_0-rmse:29.90718	validation_1-rmse:35.10451
# [193]	validation_0-rmse:29.61485	validation_1-rmse:34.74968
# [194]	validation_0-rmse:29.32541	validation_1-rmse:34.39881
# [195]	validation_0-rmse:29.03886	validation_1-rmse:34.05964
# [196]	validation_0-rmse:28.75508	validation_1-rmse:33.72372
# [197]	validation_0-rmse:28.47421	validation_1-rmse:33.39049
# [198]	validation_0-rmse:28.19624	validation_1-rmse:33.05322
# [199]	validation_0-rmse:27.92099	validation_1-rmse:32.72672
# [200]	validation_0-rmse:27.64860	validation_1-rmse:32.39082
# [201]	validation_0-rmse:27.37886	validation_1-rmse:32.07091
# [202]	validation_0-rmse:27.11188	validation_1-rmse:31.75513
# [203]	validation_0-rmse:26.84758	validation_1-rmse:31.43265
# [204]	validation_0-rmse:26.58583	validation_1-rmse:31.12125
# [205]	validation_0-rmse:26.32658	validation_1-rmse:30.81721
# [206]	validation_0-rmse:26.07013	validation_1-rmse:30.51326
# [207]	validation_0-rmse:25.81631	validation_1-rmse:30.20008
# [208]	validation_0-rmse:25.56501	validation_1-rmse:29.90230
# [209]	validation_0-rmse:25.31619	validation_1-rmse:29.60641
# [210]	validation_0-rmse:25.06988	validation_1-rmse:29.31354
# [211]	validation_0-rmse:24.82610	validation_1-rmse:29.01644
# [212]	validation_0-rmse:24.58456	validation_1-rmse:28.73094
# [213]	validation_0-rmse:24.34561	validation_1-rmse:28.44679
# [214]	validation_0-rmse:24.10912	validation_1-rmse:28.15989
# [215]	validation_0-rmse:23.87477	validation_1-rmse:27.88733
# [216]	validation_0-rmse:23.64298	validation_1-rmse:27.61305
# [217]	validation_0-rmse:23.41358	validation_1-rmse:27.33040
# [218]	validation_0-rmse:23.18646	validation_1-rmse:27.06049
# [219]	validation_0-rmse:22.96158	validation_1-rmse:26.79199
# [220]	validation_0-rmse:22.73900	validation_1-rmse:26.52879
# [221]	validation_0-rmse:22.51870	validation_1-rmse:26.26710
# [222]	validation_0-rmse:22.30045	validation_1-rmse:26.00799
# [223]	validation_0-rmse:22.08460	validation_1-rmse:25.74144
# [224]	validation_0-rmse:21.87069	validation_1-rmse:25.49289
# [225]	validation_0-rmse:21.65915	validation_1-rmse:25.24296
# [226]	validation_0-rmse:21.44972	validation_1-rmse:24.99266
# [227]	validation_0-rmse:21.24241	validation_1-rmse:24.74709
# [228]	validation_0-rmse:21.03726	validation_1-rmse:24.49508
# [229]	validation_0-rmse:20.83416	validation_1-rmse:24.25411
# [230]	validation_0-rmse:20.63309	validation_1-rmse:24.01595
# [231]	validation_0-rmse:20.43390	validation_1-rmse:23.78100
# [232]	validation_0-rmse:20.23692	validation_1-rmse:23.54757
# [233]	validation_0-rmse:20.04195	validation_1-rmse:23.31025
# [234]	validation_0-rmse:19.84890	validation_1-rmse:23.08180
# [235]	validation_0-rmse:19.65785	validation_1-rmse:22.85051
# [236]	validation_0-rmse:19.46855	validation_1-rmse:22.62922
# [237]	validation_0-rmse:19.28134	validation_1-rmse:22.40783
# [238]	validation_0-rmse:19.09603	validation_1-rmse:22.18627
# [239]	validation_0-rmse:18.91267	validation_1-rmse:21.96119
# [240]	validation_0-rmse:18.73095	validation_1-rmse:21.74987
# [241]	validation_0-rmse:18.55124	validation_1-rmse:21.53756
# [242]	validation_0-rmse:18.37334	validation_1-rmse:21.32680
# [243]	validation_0-rmse:18.19730	validation_1-rmse:21.11825
# [244]	validation_0-rmse:18.02309	validation_1-rmse:20.90537
# [245]	validation_0-rmse:17.85045	validation_1-rmse:20.70392
# [246]	validation_0-rmse:17.67973	validation_1-rmse:20.50232
# [247]	validation_0-rmse:17.51079	validation_1-rmse:20.29455
# [248]	validation_0-rmse:17.34354	validation_1-rmse:20.09716
# [249]	validation_0-rmse:17.17800	validation_1-rmse:19.89888
# [250]	validation_0-rmse:17.01417	validation_1-rmse:19.70502
# [251]	validation_0-rmse:16.85200	validation_1-rmse:19.51608
# [252]	validation_0-rmse:16.69156	validation_1-rmse:19.31773
# [253]	validation_0-rmse:16.53273	validation_1-rmse:19.12435
# [254]	validation_0-rmse:16.37549	validation_1-rmse:18.93402
# [255]	validation_0-rmse:16.21974	validation_1-rmse:18.75005
# [256]	validation_0-rmse:16.06572	validation_1-rmse:18.57087
# [257]	validation_0-rmse:15.91334	validation_1-rmse:18.38319
# [258]	validation_0-rmse:15.76233	validation_1-rmse:18.20599
# [259]	validation_0-rmse:15.61302	validation_1-rmse:18.03033
# [260]	validation_0-rmse:15.46527	validation_1-rmse:17.85577
# [261]	validation_0-rmse:15.31899	validation_1-rmse:17.67895
# [262]	validation_0-rmse:15.17414	validation_1-rmse:17.51087
# [263]	validation_0-rmse:15.03093	validation_1-rmse:17.33731
# [264]	validation_0-rmse:14.88921	validation_1-rmse:17.16258
# [265]	validation_0-rmse:14.74879	validation_1-rmse:16.99599
# [266]	validation_0-rmse:14.60995	validation_1-rmse:16.83475
# [267]	validation_0-rmse:14.47254	validation_1-rmse:16.67352
# [268]	validation_0-rmse:14.33658	validation_1-rmse:16.51572
# [269]	validation_0-rmse:14.20205	validation_1-rmse:16.35181
# [270]	validation_0-rmse:14.06886	validation_1-rmse:16.19387
# [271]	validation_0-rmse:13.93692	validation_1-rmse:16.04074
# [272]	validation_0-rmse:13.80650	validation_1-rmse:15.88925
# [273]	validation_0-rmse:13.67744	validation_1-rmse:15.73343
# [274]	validation_0-rmse:13.54973	validation_1-rmse:15.58236
# [275]	validation_0-rmse:13.42335	validation_1-rmse:15.42959
# [276]	validation_0-rmse:13.29828	validation_1-rmse:15.28455
# [277]	validation_0-rmse:13.17450	validation_1-rmse:15.14108
# [278]	validation_0-rmse:13.05207	validation_1-rmse:14.99164
# [279]	validation_0-rmse:12.93088	validation_1-rmse:14.85128
# [280]	validation_0-rmse:12.81081	validation_1-rmse:14.70693
# [281]	validation_0-rmse:12.69219	validation_1-rmse:14.56484
# [282]	validation_0-rmse:12.57479	validation_1-rmse:14.42427
# [283]	validation_0-rmse:12.45862	validation_1-rmse:14.28995
# [284]	validation_0-rmse:12.34350	validation_1-rmse:14.15491
# [285]	validation_0-rmse:12.22976	validation_1-rmse:14.01548
# [286]	validation_0-rmse:12.11717	validation_1-rmse:13.88338
# [287]	validation_0-rmse:12.00578	validation_1-rmse:13.75273
# [288]	validation_0-rmse:11.89552	validation_1-rmse:13.61921
# [289]	validation_0-rmse:11.78649	validation_1-rmse:13.49147
# [290]	validation_0-rmse:11.67861	validation_1-rmse:13.36175
# [291]	validation_0-rmse:11.57193	validation_1-rmse:13.23443
# [292]	validation_0-rmse:11.46637	validation_1-rmse:13.11332
# [293]	validation_0-rmse:11.36194	validation_1-rmse:12.99215
# [294]	validation_0-rmse:11.25846	validation_1-rmse:12.86726
# [295]	validation_0-rmse:11.15601	validation_1-rmse:12.74477
# [296]	validation_0-rmse:11.05487	validation_1-rmse:12.62894
# [297]	validation_0-rmse:10.95479	validation_1-rmse:12.50689
# [298]	validation_0-rmse:10.85581	validation_1-rmse:12.39356
# [299]	validation_0-rmse:10.75787	validation_1-rmse:12.27710
# [300]	validation_0-rmse:10.66099	validation_1-rmse:12.16630
# [301]	validation_0-rmse:10.56491	validation_1-rmse:12.05114
# [302]	validation_0-rmse:10.47009	validation_1-rmse:11.94171
# [303]	validation_0-rmse:10.37629	validation_1-rmse:11.82733
# [304]	validation_0-rmse:10.28350	validation_1-rmse:11.72147
# [305]	validation_0-rmse:10.19150	validation_1-rmse:11.61139
# [306]	validation_0-rmse:10.10075	validation_1-rmse:11.50380
# [307]	validation_0-rmse:10.01097	validation_1-rmse:11.40254
# [308]	validation_0-rmse:9.92212	validation_1-rmse:11.29468
# [309]	validation_0-rmse:9.83426	validation_1-rmse:11.19366
# [310]	validation_0-rmse:9.74732	validation_1-rmse:11.08848
# [311]	validation_0-rmse:9.66136	validation_1-rmse:10.99162
# [312]	validation_0-rmse:9.57618	validation_1-rmse:10.88962
# [313]	validation_0-rmse:9.49186	validation_1-rmse:10.79151
# [314]	validation_0-rmse:9.40849	validation_1-rmse:10.69794
# [315]	validation_0-rmse:9.32623	validation_1-rmse:10.59981
# [316]	validation_0-rmse:9.24469	validation_1-rmse:10.50132
# [317]	validation_0-rmse:9.16418	validation_1-rmse:10.41043
# [318]	validation_0-rmse:9.08433	validation_1-rmse:10.31558
# [319]	validation_0-rmse:9.00558	validation_1-rmse:10.22736
# [320]	validation_0-rmse:8.92745	validation_1-rmse:10.13697
# [321]	validation_0-rmse:8.85041	validation_1-rmse:10.04558
# [322]	validation_0-rmse:8.77423	validation_1-rmse:9.95985
# [323]	validation_0-rmse:8.69899	validation_1-rmse:9.87057
# [324]	validation_0-rmse:8.62430	validation_1-rmse:9.78732
# [325]	validation_0-rmse:8.55062	validation_1-rmse:9.70418
# [326]	validation_0-rmse:8.47780	validation_1-rmse:9.62275
# [327]	validation_0-rmse:8.40574	validation_1-rmse:9.53738
# [328]	validation_0-rmse:8.33434	validation_1-rmse:9.45829
# [329]	validation_0-rmse:8.26386	validation_1-rmse:9.37931
# [330]	validation_0-rmse:8.19425	validation_1-rmse:9.30179
# [331]	validation_0-rmse:8.12513	validation_1-rmse:9.22055
# [332]	validation_0-rmse:8.05705	validation_1-rmse:9.14462
# [333]	validation_0-rmse:7.98959	validation_1-rmse:9.06492
# [334]	validation_0-rmse:7.92262	validation_1-rmse:8.99019
# [335]	validation_0-rmse:7.85685	validation_1-rmse:8.91329
# [336]	validation_0-rmse:7.79171	validation_1-rmse:8.83521
# [337]	validation_0-rmse:7.72692	validation_1-rmse:8.76333
# [338]	validation_0-rmse:7.66291	validation_1-rmse:8.69074
# [339]	validation_0-rmse:7.60001	validation_1-rmse:8.62076
# [340]	validation_0-rmse:7.53759	validation_1-rmse:8.54807
# [341]	validation_0-rmse:7.47593	validation_1-rmse:8.48098
# [342]	validation_0-rmse:7.41509	validation_1-rmse:8.41187
# [343]	validation_0-rmse:7.35472	validation_1-rmse:8.34197
# [344]	validation_0-rmse:7.29510	validation_1-rmse:8.27651
# [345]	validation_0-rmse:7.23630	validation_1-rmse:8.21271
# [346]	validation_0-rmse:7.17770	validation_1-rmse:8.14724
# [347]	validation_0-rmse:7.12021	validation_1-rmse:8.08418
# [348]	validation_0-rmse:7.06317	validation_1-rmse:8.02209
# [349]	validation_0-rmse:7.00687	validation_1-rmse:7.95852
# [350]	validation_0-rmse:6.95116	validation_1-rmse:7.89807
# [351]	validation_0-rmse:6.89607	validation_1-rmse:7.83593
# [352]	validation_0-rmse:6.84162	validation_1-rmse:7.77710
# [353]	validation_0-rmse:6.78809	validation_1-rmse:7.71612
# [354]	validation_0-rmse:6.73482	validation_1-rmse:7.65511
# [355]	validation_0-rmse:6.68242	validation_1-rmse:7.59655
# [356]	validation_0-rmse:6.63057	validation_1-rmse:7.54027
# [357]	validation_0-rmse:6.57930	validation_1-rmse:7.48295
# [358]	validation_0-rmse:6.52863	validation_1-rmse:7.42822
# [359]	validation_0-rmse:6.47844	validation_1-rmse:7.37117
# [360]	validation_0-rmse:6.42912	validation_1-rmse:7.31570
# [361]	validation_0-rmse:6.38003	validation_1-rmse:7.26064
# [362]	validation_0-rmse:6.33161	validation_1-rmse:7.20945
# [363]	validation_0-rmse:6.28360	validation_1-rmse:7.15584
# [364]	validation_0-rmse:6.23644	validation_1-rmse:7.10412
# [365]	validation_0-rmse:6.18988	validation_1-rmse:7.05489
# [366]	validation_0-rmse:6.14378	validation_1-rmse:7.00414
# [367]	validation_0-rmse:6.09841	validation_1-rmse:6.96205
# [368]	validation_0-rmse:6.05351	validation_1-rmse:6.91439
# [369]	validation_0-rmse:6.00890	validation_1-rmse:6.86607
# [370]	validation_0-rmse:5.96506	validation_1-rmse:6.81978
# [371]	validation_0-rmse:5.92176	validation_1-rmse:6.77415
# [372]	validation_0-rmse:5.87902	validation_1-rmse:6.72732
# [373]	validation_0-rmse:5.83666	validation_1-rmse:6.68302
# [374]	validation_0-rmse:5.79460	validation_1-rmse:6.63667
# [375]	validation_0-rmse:5.75335	validation_1-rmse:6.59363
# [376]	validation_0-rmse:5.71239	validation_1-rmse:6.54864
# [377]	validation_0-rmse:5.67193	validation_1-rmse:6.50685
# [378]	validation_0-rmse:5.63197	validation_1-rmse:6.46647
# [379]	validation_0-rmse:5.59276	validation_1-rmse:6.42589
# [380]	validation_0-rmse:5.55372	validation_1-rmse:6.38649
# [381]	validation_0-rmse:5.51526	validation_1-rmse:6.34720
# [382]	validation_0-rmse:5.47720	validation_1-rmse:6.30854
# [383]	validation_0-rmse:5.43974	validation_1-rmse:6.26977
# [384]	validation_0-rmse:5.40252	validation_1-rmse:6.23192
# [385]	validation_0-rmse:5.36604	validation_1-rmse:6.19485
# [386]	validation_0-rmse:5.33003	validation_1-rmse:6.15854
# [387]	validation_0-rmse:5.29441	validation_1-rmse:6.12214
# [388]	validation_0-rmse:5.25902	validation_1-rmse:6.08545
# [389]	validation_0-rmse:5.22411	validation_1-rmse:6.04839
# [390]	validation_0-rmse:5.18955	validation_1-rmse:6.01496
# [391]	validation_0-rmse:5.15570	validation_1-rmse:5.98120
# [392]	validation_0-rmse:5.12188	validation_1-rmse:5.94858
# [393]	validation_0-rmse:5.08897	validation_1-rmse:5.91614
# [394]	validation_0-rmse:5.05637	validation_1-rmse:5.88395
# [395]	validation_0-rmse:5.02406	validation_1-rmse:5.85062
# [396]	validation_0-rmse:4.99214	validation_1-rmse:5.81944
# [397]	validation_0-rmse:4.96082	validation_1-rmse:5.78876
# [398]	validation_0-rmse:4.92916	validation_1-rmse:5.76160
# [399]	validation_0-rmse:4.89827	validation_1-rmse:5.73189
# [400]	validation_0-rmse:4.86799	validation_1-rmse:5.70750
# [401]	validation_0-rmse:4.83787	validation_1-rmse:5.67865
# [402]	validation_0-rmse:4.80801	validation_1-rmse:5.65042
# [403]	validation_0-rmse:4.77818	validation_1-rmse:5.62307
# [404]	validation_0-rmse:4.74946	validation_1-rmse:5.59608
# [405]	validation_0-rmse:4.72061	validation_1-rmse:5.56809
# [406]	validation_0-rmse:4.69195	validation_1-rmse:5.54199
# [407]	validation_0-rmse:4.66407	validation_1-rmse:5.51495
# [408]	validation_0-rmse:4.63564	validation_1-rmse:5.49249
# [409]	validation_0-rmse:4.60832	validation_1-rmse:5.46638
# [410]	validation_0-rmse:4.58110	validation_1-rmse:5.44155
# [411]	validation_0-rmse:4.55456	validation_1-rmse:5.41632
# [412]	validation_0-rmse:4.52797	validation_1-rmse:5.39527
# [413]	validation_0-rmse:4.50212	validation_1-rmse:5.37092
# [414]	validation_0-rmse:4.47652	validation_1-rmse:5.34728
# [415]	validation_0-rmse:4.45086	validation_1-rmse:5.32476
# [416]	validation_0-rmse:4.42574	validation_1-rmse:5.30359
# [417]	validation_0-rmse:4.40047	validation_1-rmse:5.28614
# [418]	validation_0-rmse:4.37616	validation_1-rmse:5.26387
# [419]	validation_0-rmse:4.35236	validation_1-rmse:5.24205
# [420]	validation_0-rmse:4.32840	validation_1-rmse:5.21950
# [421]	validation_0-rmse:4.30472	validation_1-rmse:5.20240
# [422]	validation_0-rmse:4.28129	validation_1-rmse:5.18097
# [423]	validation_0-rmse:4.25808	validation_1-rmse:5.16640
# [424]	validation_0-rmse:4.23576	validation_1-rmse:5.14645
# [425]	validation_0-rmse:4.21368	validation_1-rmse:5.12719
# [426]	validation_0-rmse:4.19183	validation_1-rmse:5.10781
# [427]	validation_0-rmse:4.17012	validation_1-rmse:5.09253
# [428]	validation_0-rmse:4.14864	validation_1-rmse:5.07985
# [429]	validation_0-rmse:4.12760	validation_1-rmse:5.06120
# [430]	validation_0-rmse:4.10651	validation_1-rmse:5.04749
# [431]	validation_0-rmse:4.08565	validation_1-rmse:5.02911
# [432]	validation_0-rmse:4.06549	validation_1-rmse:5.01185
# [433]	validation_0-rmse:4.04530	validation_1-rmse:4.99824
# [434]	validation_0-rmse:4.02499	validation_1-rmse:4.98113
# [435]	validation_0-rmse:4.00520	validation_1-rmse:4.96409
# [436]	validation_0-rmse:3.98609	validation_1-rmse:4.94811
# [437]	validation_0-rmse:3.96689	validation_1-rmse:4.93773
# [438]	validation_0-rmse:3.94776	validation_1-rmse:4.92763
# [439]	validation_0-rmse:3.92928	validation_1-rmse:4.91256
# [440]	validation_0-rmse:3.91057	validation_1-rmse:4.90513
# [441]	validation_0-rmse:3.89276	validation_1-rmse:4.88975
# [442]	validation_0-rmse:3.87484	validation_1-rmse:4.87436
# [443]	validation_0-rmse:3.85734	validation_1-rmse:4.86052
# [444]	validation_0-rmse:3.83990	validation_1-rmse:4.84577
# [445]	validation_0-rmse:3.82272	validation_1-rmse:4.83134
# [446]	validation_0-rmse:3.80582	validation_1-rmse:4.81768
# [447]	validation_0-rmse:3.78909	validation_1-rmse:4.80499
# [448]	validation_0-rmse:3.77263	validation_1-rmse:4.79788
# [449]	validation_0-rmse:3.75639	validation_1-rmse:4.78830
# [450]	validation_0-rmse:3.74037	validation_1-rmse:4.77574
# [451]	validation_0-rmse:3.72459	validation_1-rmse:4.76408
# [452]	validation_0-rmse:3.70901	validation_1-rmse:4.75771
# [453]	validation_0-rmse:3.69359	validation_1-rmse:4.74612
# [454]	validation_0-rmse:3.67820	validation_1-rmse:4.74052
# [455]	validation_0-rmse:3.66323	validation_1-rmse:4.72929
# [456]	validation_0-rmse:3.64864	validation_1-rmse:4.71922
# [457]	validation_0-rmse:3.63400	validation_1-rmse:4.71403
# [458]	validation_0-rmse:3.61970	validation_1-rmse:4.70407
# [459]	validation_0-rmse:3.60564	validation_1-rmse:4.69382
# [460]	validation_0-rmse:3.59205	validation_1-rmse:4.68463
# [461]	validation_0-rmse:3.57771	validation_1-rmse:4.68045
# [462]	validation_0-rmse:3.56398	validation_1-rmse:4.67086
# [463]	validation_0-rmse:3.55076	validation_1-rmse:4.66234
# [464]	validation_0-rmse:3.53732	validation_1-rmse:4.65861
# [465]	validation_0-rmse:3.52370	validation_1-rmse:4.65383
# [466]	validation_0-rmse:3.51089	validation_1-rmse:4.64577
# [467]	validation_0-rmse:3.49792	validation_1-rmse:4.63874
# [468]	validation_0-rmse:3.48546	validation_1-rmse:4.63051
# [469]	validation_0-rmse:3.47295	validation_1-rmse:4.62323
# [470]	validation_0-rmse:3.46047	validation_1-rmse:4.61660
# [471]	validation_0-rmse:3.44823	validation_1-rmse:4.60886
# [472]	validation_0-rmse:3.43592	validation_1-rmse:4.60224
# [473]	validation_0-rmse:3.42435	validation_1-rmse:4.59491
# [474]	validation_0-rmse:3.41224	validation_1-rmse:4.59148
# [475]	validation_0-rmse:3.40048	validation_1-rmse:4.58531
# [476]	validation_0-rmse:3.38914	validation_1-rmse:4.57848
# [477]	validation_0-rmse:3.37811	validation_1-rmse:4.57182
# [478]	validation_0-rmse:3.36689	validation_1-rmse:4.56609
# [479]	validation_0-rmse:3.35560	validation_1-rmse:4.56033
# [480]	validation_0-rmse:3.34449	validation_1-rmse:4.55484
# [481]	validation_0-rmse:3.33389	validation_1-rmse:4.54873
# [482]	validation_0-rmse:3.32344	validation_1-rmse:4.54282
# [483]	validation_0-rmse:3.31282	validation_1-rmse:4.53773
# [484]	validation_0-rmse:3.30270	validation_1-rmse:4.53206
# [485]	validation_0-rmse:3.29267	validation_1-rmse:4.52658
# [486]	validation_0-rmse:3.28271	validation_1-rmse:4.52151
# [487]	validation_0-rmse:3.27291	validation_1-rmse:4.51656
# [488]	validation_0-rmse:3.26314	validation_1-rmse:4.51192
# [489]	validation_0-rmse:3.25352	validation_1-rmse:4.50692
# [490]	validation_0-rmse:3.24414	validation_1-rmse:4.50324
# [491]	validation_0-rmse:3.23483	validation_1-rmse:4.49878
# [492]	validation_0-rmse:3.22556	validation_1-rmse:4.49464
# [493]	validation_0-rmse:3.21654	validation_1-rmse:4.49129
# [494]	validation_0-rmse:3.20764	validation_1-rmse:4.48716
# [495]	validation_0-rmse:3.19879	validation_1-rmse:4.48329
# [496]	validation_0-rmse:3.19011	validation_1-rmse:4.48041
# [497]	validation_0-rmse:3.18164	validation_1-rmse:4.47752
# [498]	validation_0-rmse:3.17279	validation_1-rmse:4.47356
# [499]	validation_0-rmse:3.16434	validation_1-rmse:4.46971
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# We'll now see how the RMSE-score looks like:

# %%
y_pred = xgb.predict(X_test)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 4.46970546223107

# %% [markdown]
# Let's also make a graph to visualize the output

# %%
train,test=split(close_df,date)
test['prediction'] = xgb.predict(X_test)
test['prediction'] = xgb.predict(X_test)
df = close_df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df.tail(20)[['MSFT']].plot(figsize=(15, 5)) #month
df.tail(20)['prediction'].plot(ax=ax)
plt.legend(['Real stock price', 'Predicted value'])
ax.set_title('Predicted values')
plt.show()

# %% [markdown]
# We are happy with this result. Hence we can finalize the model by using all the data

# %%
#Finalization
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=500, early_stopping_rounds=50, learning_rate=0.01, max_depth=7)
xgb.fit(X, y, eval_set=[(X, y)], verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# We can now make a prediction for the 5 coming days:

# %%
def predict_head(X):
    """
    CAREFUL!!
    This function will only predict the future 5 business days 
    as from January 1st, 2023.  
    """
    date_list = [pd.to_datetime('2023-01-03'), pd.to_datetime('2023-01-04'), pd.to_datetime('2023-01-05'), pd.to_datetime('2023-01-06'), pd.to_datetime('2023-01-09')]
    start_values = {'t-1': xgb.predict(X.iloc[-1:])[0], 't-2': X.iloc[-1,0]}

    # Loop over the next five days
    for day in date_list:
        values = {'t-1': xgb.predict(X.iloc[-1:])[0], 't-2': X.iloc[-1,0]}
        X = X.append(pd.DataFrame(values, index=[day]))
    
    y_predict=xgb.predict(X.tail())
    return y_predict

y_predict=predict_head(X)

# %% [markdown]
# We can now also compare with the actual values:

# %%
stock_list = ['MSFT', 'MMC', 'NI', 'BAX', 'CNP', 'TGT', 'JPM', 'BA']
close_df=get_data("20230101","20230110",stock_list)
future=close_df[['MSFT']]
future['predicted']=y_predict
future
# Out:
#                   MSFT   predicted
# Date
# 2023-01-03  238.981430  239.348328
# 2023-01-04  228.527618  239.012451
# 2023-01-05  221.754562  238.474243
# 2023-01-06  224.368011  238.504074
# 2023-01-09  226.552551  238.485367

# %% [markdown]
# Save the model

# %%
xgb.save_model("./model/xgbmodel.bin")
